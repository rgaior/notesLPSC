# %% [markdown]
# #intro

# %%
# %matplotlib inline

# %% [markdown]
# This is a collection of plots on the monitoring of the helix antennas.

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analysis/txtdata/analysis/')
# %run meanandvar.py
