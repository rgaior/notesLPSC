# %% [markdown]
# #intro

# %% [markdown]
# A set of plots about the Helix adaptation board measurement

# %% [markdown]
# #Vout vs Pin

# %% [markdown]
# - setup:
# Signal Generator (SG) -- bias T -- **helix box** -- scope
# - acquisition:
# scope Lecroy (400MHz analog BW) / Time base: 2us / ~ 10 wf recorder
# - folder:
# '/Users/romain/work/Auger/EASIER/data/meas/board/20160201/measure1'

# %% [markdown]
# Example of waveform:

# %%
# %matplotlib inline

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/measboard/test/')
# %run readwf.py
# Out:
# /Users/romain/work/Auger/EASIER/data/meas/board/20160201/measure1/C1-25dbm00006.txt

# %% [markdown]
# The curve $V_{out} = f (P_{in})$:

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/measboard/analysis/')
# %run fitcarac.py

# %% [markdown]
# Here for each input power we have several measures, they enter in the fit, but they can't be seen on the plot because they overlap.
# The slope is very close to what we had before.
