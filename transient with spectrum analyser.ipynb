# %% [markdown]
# # devices

# %% [markdown]
# - signal generator: Agilent N5181A
# - spectrum analyser: RS FSH6 (100kHz - 6 GHz)

# %% [markdown]
# # basics

# %% [markdown]
# we start the note with basic measurements:

# %% [markdown]
# ##power measurement / RBW

# %%
# %matplotlib inline

# %% [markdown]
# setup:
# - SG-->SA
# - detector : Max peak/ Trigger: free
# - $\rm F_{emit}$ = 1GHz / CW / P = -10dBm
# - rec: RBW:1MHz
# - data:s1

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s1.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (500ns/1us)** / P = -10dBm
# - rec: RBW:1MHz
# - data: s2

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s2.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/1us)** / P = -10dBm
# - rec: RBW:1MHz
# - data: s3

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s3.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / CW / P = -10dBm
# - rec: RBW:100kHz
# - data: s4

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s4.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (500ns/1us)** / P = -10dBm
# - rec: RBW:100kHz
# - data: s5

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s5.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/1us)** / P = -10dBm
# - rec: RBW:100kHz
# - data: s6

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s6.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (500ns/2us)** / P = -10dBm
# - rec: RBW:100kHz
# - data: s7

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s7.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/2us)** / P = -10dBm
# - rec: RBW:100kHz
# - data: s8

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s8.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (500ns/1us)** / P = -10dBm
# - span 250MHz
# - rec: RBW:100kHz
# - data: s9

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s9.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/1us)** / P = -10dBm
# - span 250MHz
# - rec: RBW:100kHz
# - data: s10

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s10.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (1us/10us)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - data: s11

# %%
import os
os.chdir('/Users/romain/work/Auger/EASIER/LPSC/analyser/test/')
# %run plotspec.py s11.

# %% [markdown]
# ### low rate signal

# %% [markdown]
# To observe transient signal with a low rate, the method is to increase the sweep time, that means that the SA will spend more time on each point and have more chance to catch the transient.

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (1us/1ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 20ms
# - data: data12

# %%
# %run plotspec.py data12

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (1us/1ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 100ms
# - data: data13

# %%
# %run plotspec.py data13

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (1us/1ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 1000ms
# - data: data14

# %%
# %run plotspec.py data14

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (1us/10ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 100ms
# - data: data15

# %%
# %run plotspec.py data15

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (1us/10ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 1000 ms
# - data: data16

# %%
# %run plotspec.py data16

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (1us/10ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 10000 ms
# - data: data17

# %%
# %run plotspec.py data17

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/10ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 100 ms
# - data: data18

# %%
# %run plotspec.py data18

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/10ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 1000 ms
# - data: data19

# %%
# %run plotspec.py data19

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/10ms)** / P = -10dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 10000 ms
# - data: data20

# %%
# %run plotspec.py data20

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/10ms)** / P = -20dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 10000 ms
# - data: data21

# %%
# %run plotspec.py data21

# %% [markdown]
# - $\rm F_{emit}$ = 1GHz / **pulse (100ns/10ms)** / P = -20dBm
# - span 500MHz
# - rec: RBW:100kHz
# - sweep time: 10000 ms
# - ref level: -30
# - data: data22

# %%
# %run plotspec.py data22
