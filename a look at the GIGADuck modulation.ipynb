# %%
# %load_ext autoreload
# %autoreload 2
#new way to load data
# the basic cuts are already in the select leaf
# %matplotlib inline 
srcpwd = '/Users/romain/work/Auger/EASIER/LPSC/monitoring/script'
utilspath =srcpwd + '/utils/'
sys.path.append(utilspath)
import utils
classpath = srcpwd + '/classes/'
sys.path.append(classpath)
import dataset
#datafolder = '/Users/romain/work/Auger/EASIER/LPSC/monitoring/data/332_333/'
datafolder = '/Users/romain/work/Auger/EASIER/LPSC/monitoring/data/easier7/'
fname = 'Antenna_2015-03-15_2015-05-30.root'
#fname = 'Antenna_2014-01-01_2014-12-31.root'                                                                                                        
file = datafolder + fname

data = dataset.Dataset(file)
data.loaddata()
pfile = '/Users/romain/work/Auger/EASIER/LPSC/suntransit/data/period/controlperiod_Tsys_50K_below_2adc.txt'
data.loadperiod(pfile)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#load the data for 432
data1 = data.getnewdatawithid(332)
data1.selectleafs()
ndata1 = data1.getnewdatasetcond(np.where((data1.humLL < 50) ))
ndata1.filterHP(1.5)
ndata1.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndata1.hhmm,ndata1.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 333
data2 = data.getnewdatawithid(333)
data2.selectleafs()
ndata2 = data2.getnewdatasetcond(np.where((data2.humLL < 50) ))
ndata2.filterHP(1.5)
ndata2.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndata2.hhmm,ndata2.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 431
data3 = data.getnewdatawithid(341)
data3.selectleafs()
ndata3 = data3.getnewdatasetcond(np.where((data3.humLL < 50) ))
ndata3.filterHP(1.5)
ndata3.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndata3.hhmm,ndata3.radioc,'.')
plt.ylim(-40,40)
# Out:
# (-40, 40)

# %%
#load the data for 342
data4 = data.getnewdatawithid(342)
data4.selectleafs()
#ndata4 = data4.getnewdatasetcond(np.where((data4.humLL < 50) & (data4.hhmm > 1500) ))
ndata4 = data4.getnewdatasetcond(np.where((data4.humLL < 50) ))
ndata4.filterHP(1.5)
ndata4.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndata4.hhmm,ndata4.radioc,'.')
plt.ylim(-40,40)
# Out:
# (-40, 40)

# %%
#load the data for 343
data5 = data.getnewdatawithid(343)
data5.selectleafs()
ndata5 = data5.getnewdatasetcond(np.where((data5.humLL < 50) ))
ndata5.filterHP(1.5)
ndata5.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndata5.hhmm,ndata5.radioc,'.')
plt.ylim(-40,40)
# Out:
# (-40, 40)

# %%
#load the data for 344
data6 = data.getnewdatawithid(344)
data6.selectleafs()
#ndata6 = data6.getnewdatasetcond(np.where((data6.humLL < 50) & (data6.hhmm > 1500) ))
ndata6 = data6.getnewdatasetcond(np.where((data6.humLL < 50) ))
ndata6.filterHP(1.5)
ndata6.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndata6.hhmm,ndata6.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 419
data7 = data.getnewdatawithid(419)
data7.selectleafs()
ndata7 = data7.getnewdatasetcond(np.where((data7.humLL < 50) ))
ndata7.filterHP(1.5)
ndata7.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndata7.hhmm,ndata7.radioc,'.')
plt.ylim(-40,40)
# Out:
# (-40, 40)

# %%
#new way to load data
# the basic cuts are already in the select leaf
# %matplotlib inline 
srcpwd = '/Users/romain/work/Auger/EASIER/LPSC/monitoring/script'
utilspath =srcpwd + '/utils/'
sys.path.append(utilspath)
import utils
classpath = srcpwd + '/classes/'
sys.path.append(classpath)
import dataset
datafolderGD = '/Users/romain/work/Auger/EASIER/LPSC/monitoring/data/GIGADuck/'
fnameGD = 'Antenna_2015-03-15_2015-05-30.root'
fileGD = datafolderGD + fnameGD

dataGD = dataset.Dataset(fileGD)
dataGD.loaddata()

#pfile = '/Users/romain/work/Auger/EASIER/LPSC/suntransit/data/period/controlperiod_Tsys_50K_below_2adc.txt'
#data.loadperiod(pfile)                                                                                                                              
#dataGD.selectleafs(385)

# %%
#load the data for 385
dataGD1 = dataGD.getnewdatawithid(385)
#pfile = '/Users/romain/work/Auger/EASIER/LPSC/suntransit/data/period/controlperiod_Tsys_50K_below_2adc.txt'
#dataGD1.loadperiod(pfile)                                                                                                                       
dataGD1.selectleafs()

# %%
ndataGD1 = dataGD1.getnewdatasetcond(np.where((dataGD1.humLL < 50) ))
ndataGD1.filterHP(1.5)
ndataGD1.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndataGD1.hhmm,ndataGD1.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 433
dataGD2 = dataGD.getnewdatawithid(433)
#pfile = '/Users/romain/work/Auger/EASIER/LPSC/suntransit/data/period/controlperiod_Tsys_50K_below_2adc.txt'
#dataGD1.loadperiod(pfile)                                                                                                                       
dataGD2.selectleafs()

# %%
ndataGD2 = dataGD2.getnewdatasetcond(np.where((dataGD2.humLL < 50) ))
ndataGD2.filterHP(1.5)
ndataGD2.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndataGD2.hhmm,ndataGD2.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 422
dataGD3 = dataGD.getnewdatawithid(422)
dataGD3.selectleafs()
ndataGD3 = dataGD3.getnewdatasetcond(np.where((dataGD3.humLL < 50) ))
ndataGD3.filterHP(1.5)
ndataGD3.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndataGD3.hhmm,ndataGD3.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 431
dataGD4 = dataGD.getnewdatawithid(431)
dataGD4.selectleafs()
ndataGD4 = dataGD4.getnewdatasetcond(np.where((dataGD4.humLL < 50) ))
ndataGD4.filterHP(1.5)
ndataGD4.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndataGD4.hhmm,ndataGD4.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 384
dataGD5 = dataGD.getnewdatawithid(384)
dataGD5.selectleafs()
ndataGD5 = dataGD5.getnewdatasetcond(np.where((dataGD5.humLL < 50) ))
ndataGD5.filterHP(1.5)
ndataGD5.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndataGD5.hhmm,ndataGD5.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 427
dataGD6 = dataGD.getnewdatawithid(427)
dataGD6.selectleafs()
ndataGD6 = dataGD6.getnewdatasetcond(np.where((dataGD6.humLL < 50) ))
ndataGD6.filterHP(1.5)
ndataGD6.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndataGD6.hhmm,ndataGD6.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)

# %%
#load the data for 432
dataGD7 = dataGD.getnewdatawithid(432)
dataGD7.selectleafs()
ndataGD7 = dataGD7.getnewdatasetcond(np.where((dataGD7.humLL < 50) ))
ndataGD7.filterHP(1.5)
ndataGD7.tempcorrection(1)
fig = plt.figure(figsize=(10,5))
plt.plot(ndataGD7.hhmm,ndataGD7.radioc,'.')
plt.ylim(-30,30)
# Out:
# (-30, 30)
